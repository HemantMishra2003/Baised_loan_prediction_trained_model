# %%
            # Linear Regression

# a. Simple linear regression
# one input one output
# lower dimension uses

# b. Multiple linear regression
# more than one input and one output
# things works in higher dimensions

# c. polynomial linear regression

# go to soft notes for more deeper understanding
# for 3 d equations of regression and for hyperplotting....

# %%
import numpy as np
import pandas as pd

from sklearn.datasets import make_regression

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
x,y = make_regression(n_samples=100, n_features=2, n_informative =2
                      ,n_targets=1 , noise=50)

# %%
v = pd.DataFrame({'feature1':x[:,0], 'feature2':x[:,1] , 'target':y})

# %%
v.shape
# Out:
# (100, 3)

# %%
v.head()
# Out:
#    feature1  feature2      target
# 0  1.020173 -0.110541  149.210009
# 1  0.582954  0.097725   43.697528
# 2  1.301846  0.689818   95.652048
# 3  0.093953 -0.130107   69.750315
# 4  0.094352 -0.384880  -25.890753

# %%
fig = px.scatter_3d(v,x='feature1' , y = 'feature2', z='target')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,
                                                       random_state = 3)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
print("MAE" ,mean_absolute_error(y_test , y_pred))
print("MSE" ,mean_squared_error(y_test , y_pred))
print("R2 score" ,r2_score(y_test , y_pred))
# Out:
# MAE 42.133690094512815
# MSE 2601.267463059061
# R2 score 0.26899274538712215

# %%
from sklearn.linear_model import LinearRegression

# Simple linear regression without overfitting
lr = LinearRegression()
lr.fit(v[['feature1', 'feature2']], v['target'])

# Now predict the grid
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x)

z_final = lr.predict(final).reshape(10, 10)

z = z_final

final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T

# Plot
import plotly.graph_objects as go
import plotly.express as px

fig = px.scatter_3d(v, x='feature1', y='feature2', z='target')
fig.add_trace(go.Surface(x=x, y=y, z=z , colorscale='' ))
fig.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-196-1309333642.py in <cell line: 0>()
#      21
#      22 fig = px.scatter_3d(v, x='feature1', y='feature2', z='target')
# ---> 23 fig.add_trace(go.Surface(x=x, y=y, z=z , colorscale='' ))
#      24 fig.show()
#
# ...

# %%
fig = px.scatter_3d(v,x='feature1', y = 'feature2' , z = 'target')
fig.add_trace(go.Surface(x = x , y = y , z = z ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
lr.coef_
# Out:
# array([58.56600287, 40.45890071])

# %%
lr.intercept_
# Out:
# np.float64(-2.468628301155171)
